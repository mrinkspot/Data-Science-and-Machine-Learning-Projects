# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# Mostramos cómo quedo el dataset con el análisis exploratorio previamente realizado en la notebook 1.

# %%
ds_hotel=pd.read_csv('./hotels_train_filtrado.csv')
ds_trabajo = ds_hotel.copy()
ds_trabajo.head(20)
# Out:
#            hotel  lead_time  stays_in_weekend_nights  stays_in_week_nights
# 0     City Hotel   9.233333                        1                     2  \
# 1     City Hotel   9.533333                        0                     4
# 2     City Hotel   0.000000                        0                     1
# 3   Resort Hotel   6.533333                        2                     5
# 4   Resort Hotel   7.733333                        2                     1
# 5     City Hotel  11.666667                        0                     2
# 6     City Hotel   0.333333                        0                     1
# 7     City Hotel   8.400000                        2                     3
# 8     City Hotel   0.400000                        0                     4
# 9     City Hotel   2.366667                        1                     1
# 10    City Hotel  13.033333                        0                     2
# 11    City Hotel   9.700000                        0                     2
# 12  Resort Hotel   8.466667                        2                     2
# 13    City Hotel   0.666667                        2                     0
# 14  Resort Hotel   0.000000                        1                     1
# 15  Resort Hotel   0.000000                        1                     0
# 16  Resort Hotel   0.333333                        0                     1
# 17  Resort Hotel   2.400000                        2                     2
# 18  Resort Hotel   0.000000                        1                     2
# 19    City Hotel   0.100000                        0                     1
#
#    market_segment distribution_channel  is_repeated_guest
# 0          Groups                TA/TO                  0  \
# 1          Groups                TA/TO                  0
# 2       Online TA                TA/TO                  0
# 3       Online TA                TA/TO                  0
# 4          Groups                TA/TO                  0
# 5          Groups                TA/TO                  0
# 6          Direct               Direct                  0
# 7       Online TA                TA/TO                  0
# 8       Online TA                TA/TO                  0
# 9   Offline TA/TO                TA/TO                  0
# 10         Groups                TA/TO                  0
# 11  Offline TA/TO                TA/TO                  0
# 12         Groups                TA/TO                  0
# 13  Offline TA/TO                TA/TO                  0
# 14         Direct               Direct                  0
# 15         Direct               Direct                  1
# 16         Direct               Direct                  0
# 17      Online TA                TA/TO                  0
# 18         Groups            Corporate                  0
# 19      Corporate            Corporate                  0
#
#     previous_cancellations  previous_bookings_not_canceled reserved_room_type
# 0                        0                               0                  A  \
# 1                        0                               0                  A
# 2                        0                               0                  D
# 3                        0                               0                  G
# 4                        0                               0                  A
# 5                        0                               0                  A
# 6                        0                               0                  F
# 7                        0                               0                  B
# 8                        0                               0                  D
# 9                        0                               0                  D
# 10                       0                               0                  A
# 11                       0                               0                  A
# 12                       0                               0                  A
# 13                       0                               0                  A
# 14                       0                               0                  D
# 15                       0                               0                  D
# 16                       0                               0                  A
# 17                       0                               0                  D
# 18                       0                               0                  A
# 19                       0                               0                  A
#
#     ...     adr  total_of_special_requests reservation_status_date
# 0   ...  100.00                          0              2016-04-04  \
# 1   ...  101.00                          0              2016-01-22
# 2   ...  225.00                          2              2016-08-24
# 3   ...   96.00                          0              2016-11-05
# 4   ...   30.00                          0              2016-10-18
# 5   ...  140.00                          0              2015-08-11
# 6   ...   75.00                          0              2017-03-19
# 7   ...  163.63                          1              2016-07-20
# 8   ...  187.50                          1              2017-05-13
# 9   ...  142.50                          0              2016-10-24
# 10  ...   65.00                          0              2015-12-09
# 11  ...  115.00                          0              2016-02-23
# 12  ...   36.00                          0              2015-09-16
# 13  ...   85.50                          1              2016-09-27
# 14  ...   73.00                          0              2015-10-19
# 15  ...  169.00                          0              2016-07-18
# 16  ...  126.00                          0              2016-07-13
# 17  ...  101.25                          0              2016-05-03
# 18  ...   50.00                          1              2016-10-20
# 19  ...   31.00                          1              2016-02-27
#
#                                       id  is_canceled  arrival_date  region
# 0   e6d0d58a-ab96-44d3-b28f-85df1cc15f1e            0    2016-11-07  Europe  \
# 1   aba9aac2-4495-4645-a60e-90328713c999            0    2016-05-11  Europe
# 2   b345b5dc-c804-4d77-a39f-1f4e65d1f1ad            0    2016-08-23  Europe
# 3   ce1b400e-afa1-4946-bdff-004b859eb61c            0    2016-10-29  Europe
# 4   c4fbec0d-8e2e-4db2-9d4f-a6ccb9f51214            0    2016-11-26  Europe
# 5   c142b61c-3035-46e7-8cf7-3720a29d0d61            0    2016-06-17  Europe
# 6   8c4171ad-9837-4468-ac8e-8cb3d5a41b55            0    2017-03-18  Europe
# 7   3ce60033-4529-4314-be77-db4a7737f326            0    2016-08-14  Europe
# 8   7ab807a4-5e90-4205-b66e-0188696cc34b            0    2017-05-09  Europe
# 9   a0ab0509-c8b0-4a2c-9f27-21f26e186520            0    2016-10-22    Asia
# 10  07f92188-1364-4c1d-bfda-2f3c8398f738            0    2016-07-27  Europe
# 11  6b781511-54f2-4b4d-98b4-cb44cb4a958b            0    2016-08-19  Europe
# 12  6b98d118-8299-41a1-a67c-03cec3f877c2            0    2015-09-12  Europe
# 13  9d5cd6d5-c30b-4d62-a9c2-ae8d194a099d            0    2016-09-25  Europe
# 14  bcce0923-8dbf-4199-aef0-67890225bdec            0    2015-10-17  Europe
# 15  ef22a339-5d72-404c-9e62-ad9fadb9f2e2            0    2016-07-17  Europe
# 16  f79677ce-e84e-4fb4-9664-e1eb03ee5229            0    2016-07-22  Europe
# 17  356de857-bff3-443c-86e8-62d91332f547            0    2016-04-29  Europe
# 18  af5cad30-d1a3-45f4-87e3-4a8865bce5f6            0    2016-10-17  Europe
# 19  d49efe24-4b03-48e6-9abc-eafe945d911d            0    2016-02-26  Europe
#
#    agent_specified  total_guests more_than_zero_days_in_waiting_list
# 0                0             2                                   0
# 1                1             2                                   1
# 2                0             3                                   0
# 3                1             4                                   0
# 4                1             2                                   0
# 5                1             2                                   0
# 6                0             3                                   0
# 7                1             4                                   0
# 8                1             2                                   0
# 9                1             2                                   0
# 10               1             2                                   0
# 11               1             2                                   0
# 12               1             2                                   0
# 13               1             2                                   0
# 14               0             2                                   0
# 15               0             3                                   0
# 16               0             2                                   0
# 17               1             2                                   0
# 18               0             1                                   0
# 19               0             2                                   0
#
# [20 rows x 24 columns]

# %% [markdown]
# Como estamos hablando de reservaciones en hoteles, es válido tomar en cuenta las reservaciones por temporadas. De tal forma se genera una nueva variable que se le asignará una temporada correspondiente a cada dato según su fecha de llegada (LAS TEMPORADAS SON REPRESENTATIVAS)

# %%
ds_trabajo['arrival_date'] = pd.to_datetime(ds_trabajo['arrival_date'])

# Crear una nueva columna 'season' basada en los valores de la columna 'arrival_date'
ds_trabajo['season'] = pd.cut(ds_trabajo['arrival_date'].dt.month,
                              bins=[0,3,6,9,12],
                              labels=['Winter', 'Spring', 'Summer', 'Autumn'])
ds_trabajo.head()
# Out:
#           hotel  lead_time  stays_in_weekend_nights  stays_in_week_nights
# 0    City Hotel   9.233333                        1                     2  \
# 1    City Hotel   9.533333                        0                     4
# 2    City Hotel   0.000000                        0                     1
# 3  Resort Hotel   6.533333                        2                     5
# 4  Resort Hotel   7.733333                        2                     1
#
#   market_segment distribution_channel  is_repeated_guest
# 0         Groups                TA/TO                  0  \
# 1         Groups                TA/TO                  0
# 2      Online TA                TA/TO                  0
# 3      Online TA                TA/TO                  0
# 4         Groups                TA/TO                  0
#
#    previous_cancellations  previous_bookings_not_canceled reserved_room_type
# 0                       0                               0                  A  \
# 1                       0                               0                  A
# 2                       0                               0                  D
# 3                       0                               0                  G
# 4                       0                               0                  A
#
#    ... total_of_special_requests  reservation_status_date
# 0  ...                         0               2016-04-04  \
# 1  ...                         0               2016-01-22
# 2  ...                         2               2016-08-24
# 3  ...                         0               2016-11-05
# 4  ...                         0               2016-10-18
#
#                                      id is_canceled  arrival_date  region
# 0  e6d0d58a-ab96-44d3-b28f-85df1cc15f1e           0    2016-11-07  Europe  \
# 1  aba9aac2-4495-4645-a60e-90328713c999           0    2016-05-11  Europe
# 2  b345b5dc-c804-4d77-a39f-1f4e65d1f1ad           0    2016-08-23  Europe
# 3  ce1b400e-afa1-4946-bdff-004b859eb61c           0    2016-10-29  Europe
# 4  c4fbec0d-8e2e-4db2-9d4f-a6ccb9f51214           0    2016-11-26  Europe
#
#   agent_specified total_guests  more_than_zero_days_in_waiting_list  season
# 0               0            2                                    0  Autumn
# 1               1            2                                    1  Spring
# 2               0            3                                    0  Summer
# 3               1            4                                    0  Autumn
# 4               1            2                                    0  Autumn
#
# [5 rows x 25 columns]

# %%
frecuencia = ds_trabajo['season'].value_counts()

plt.xlabel('Estación del año')
plt.ylabel('Frecuencia')
plt.title('Distribución de la Estación del año')
frecuencia.plot(kind='bar')
plt.show()

# %% [markdown]
# Al agregar la variable `season` logramos ver que durante el verano es donde más reservas hay pero a su vez mas cancelaciones, mientras que en invierno y otoño disminuyen,
# pero son menos las cancelaciones

# %%
arrival_canceled = ds_trabajo[['season', 'is_canceled']]

arrival_canceled = arrival_canceled.groupby(['season', 'is_canceled']).size().reset_index(name='counts')
plt.xlabel('Frecuencia')
plt.ylabel('Temporada')
plt.title('Distribución de Temporada de llegada según cancelación')
sns.histplot(y='season', weights='counts', hue='is_canceled', multiple='stack', data=arrival_canceled, bins=35)
plt.show()

# %%
sns.countplot(x="season", hue="is_canceled", data=ds_trabajo)

plt.xlabel('Reservas en determinada temporada')
plt.ylabel('Frecuencia')
plt.title('Distribución del Total de Reservas en temporadas según Cancelación')

plt.show()

# %%
table = pd.pivot_table(ds_trabajo, values='is_canceled', index=['hotel', 'season'], columns=[], aggfunc=lambda x: x.sum()/len(x))
table
# Out:
#                      is_canceled
# hotel        season
# City Hotel   Winter            0
#              Spring            0
#              Summer            0
#              Autumn            0
# Resort Hotel Winter            0
#              Spring            0
#              Summer            0
#              Autumn            0

# %% [markdown]
# Vimos previamente que las variables `assigned_room_type` y `reserver_room_type` no tiene relacion directa con `is_canceled`, las reinterpretamos a ambas como "¿se le asignó el cuarto deseado?" y lo transformamos en una columna que puede darnos información

# %%
ds_trabajo['room_type_match'] = ds_trabajo['reserved_room_type'] == ds_trabajo['assigned_room_type']

# %% [markdown]
# De esta forma tengo una variable booleana que me indicará si se le asignó el cuarto deseado y qué relación tiene con is_canceled

# %%
tabla_frecuencia = pd.crosstab(ds_trabajo['room_type_match'], ds_trabajo['is_canceled'])
tabla_frecuencia.plot.bar(rot=0)

plt.title("Distribución de tipo de cuarto asignado comparado al solicitado según Cancelación")
plt.show()

# %% [markdown]
# Podemos ver que aunque no se le asignó el cuarto deseado, el porcentaje de cancelación es mucho más bajo. Tal vez se deba a una mejoría en la asignación por el mismo costo, por ejemplo

# %%
df = ds_trabajo.drop(ds_trabajo[ds_trabajo['assigned_room_type'] == 'A'].index) #SACO EL VALOR DE "A" PORQUE MOLESTA EN LA VISUALIZACION DEL GRAFICO
tabla_frecuencia = pd.crosstab(df['assigned_room_type'], df['room_type_match'])
tabla_frecuencia.plot.bar(rot=0)
plt.title("Distribución del tipo de cuarto asignado según si coincide con el reservado")
plt.show()

# %% [markdown]
# Guardamos el progreso sobre el dataset en uno nuevo para trabajarlo en el siguiente notebook correspondiente al checkpoint 2.

# %%
ds_trabajo.to_csv('hotels_train_filtrado.csv', index=False)
