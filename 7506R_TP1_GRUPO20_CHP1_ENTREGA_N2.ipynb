# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# Mostramos cómo quedo el dataset con el análisis exploratorio previamente realizado en la notebook 1.

# %%
ds_hotel=pd.read_csv('./hotels_train_filtrado.csv')
ds_trabajo = ds_hotel.copy()
ds_trabajo.head(20)
# Out:
#            hotel  lead_time  stays_in_weekend_nights  stays_in_week_nights  \
# 0     City Hotel   1.633333                        1                     2
# 1   Resort Hotel   0.133333                        0                     1
# 2     City Hotel   0.833333                        0                     1
# 3     City Hotel   0.866667                        2                     5
# 4     City Hotel   3.466667                        2                     5
# 5     City Hotel   0.033333                        3                     5
# 6   Resort Hotel   3.733333                        4                     9
# 7     City Hotel   6.400000                        2                     1
# 8     City Hotel   8.566667                        2                     2
# 9   Resort Hotel   0.133333                        0                     1
# 10    City Hotel   1.533333                        2                     3
# 11    City Hotel  11.633333                        1                     5
# 12  Resort Hotel   0.100000                        0                     1
# 13    City Hotel   1.366667                        0                     3
# 14  Resort Hotel   6.833333                        2                     5
# 15    City Hotel  15.500000                        0                     3
# 16    City Hotel  11.100000                        0                     2
# 17    City Hotel   0.600000                        0                     1
# 18  Resort Hotel   5.400000                        0                     3
# 19    City Hotel   0.300000                        1                     2
#
#    market_segment distribution_channel  is_repeated_guest  \
# 0       Online TA                TA/TO                  0
# 1          Groups               Direct                  0
# 2       Online TA                TA/TO                  0
# 3          Groups                TA/TO                  0
# 4   Offline TA/TO                TA/TO                  0
# 5          Direct               Direct                  0
# 6   Offline TA/TO                TA/TO                  0
# 7       Online TA                TA/TO                  0
# 8       Online TA                TA/TO                  0
# 9       Online TA                TA/TO                  0
# 10      Online TA                TA/TO                  0
# 11  Offline TA/TO                TA/TO                  0
# 12         Direct               Direct                  0
# 13         Groups                TA/TO                  0
# 14      Online TA                TA/TO                  0
# 15  Offline TA/TO                TA/TO                  0
# 16  Offline TA/TO                TA/TO                  0
# 17      Online TA                TA/TO                  0
# 18         Groups                TA/TO                  0
# 19      Online TA                TA/TO                  0
#
#     previous_cancellations  previous_bookings_not_canceled reserved_room_type  \
# 0                        0                               0                  D
# 1                        0                               0                  A
# 2                        0                               0                  F
# 3                        0                               0                  A
# 4                        0                               0                  A
# 5                        0                               0                  A
# 6                        0                               0                  D
# 7                        1                               0                  A
# 8                        0                               0                  A
# 9                        0                               0                  A
# 10                       0                               0                  A
# 11                       0                               0                  A
# 12                       0                               0                  A
# 13                       0                               0                  A
# 14                       0                               0                  D
# 15                       0                               0                  A
# 16                       1                               0                  A
# 17                       0                               0                  A
# 18                       0                               0                  A
# 19                       0                               0                  D
#
#     ...     adr  total_of_special_requests reservation_status_date  \
# 0   ...  115.50                          1              2016-08-25
# 1   ...   42.00                          0              2015-11-01
# 2   ...  229.00                          2              2016-10-14
# 3   ...   75.00                          0              2016-11-29
# 4   ...   75.00                          1              2017-03-26
# 5   ...  133.00                          0              2015-09-22
# 6   ...   66.42                          1              2015-11-25
# 7   ...   76.50                          0              2015-07-03
# 8   ...  107.10                          2              2017-06-08
# 9   ...   65.00                          2              2016-12-11
# 10  ...   77.35                          2              2016-03-15
# 11  ...   80.00                          0              2016-09-02
# 12  ...  131.00                          0              2017-04-13
# 13  ...  108.00                          0              2016-09-17
# 14  ...  144.14                          1              2016-09-17
# 15  ...  112.67                          0              2017-07-18
# 16  ...   90.00                          0              2015-11-11
# 17  ...   89.00                          0              2016-06-24
# 18  ...   84.00                          0              2016-03-27
# 19  ...  183.33                          1              2017-08-21
#
#                                       id  is_canceled  arrival_date    region  \
# 0   7aa4cc6b-b92c-4061-b21d-4f9e0cac4689            1    2016-09-05  Americas
# 1   b1428f80-c56c-4ae4-91a9-6962edae08b1            0    2015-10-31    Europe
# 2   2226c018-ea20-4c4e-8f71-ea66aee70d7c            0    2016-10-13    Europe
# 3   314f56dc-2e4d-4298-9bdd-27bb008bffff            1    2016-12-12    Europe
# 4   28c75445-c603-413a-babf-ad377018b592            0    2017-03-19    Europe
# 5   8f62c6f7-60a5-4b54-8ced-faaf9213a7a7            0    2015-09-14    Africa
# 6   c7e59753-c8a7-42eb-977b-f0ffaf1716eb            0    2015-11-12    Europe
# 7   b36e1623-aa3b-468d-bc5c-2443cfbf0fe6            1    2015-07-12    Europe
# 8   4ad12f6e-0cda-478f-bd4a-7a890f08a951            0    2017-06-04    Europe
# 9   491511e8-e916-433c-833d-c6e03f47bbdf            0    2016-12-10    Europe
# 10  3fcd8786-6e6d-4237-b7af-b9f9fdf5a65d            0    2016-03-10    Europe
# 11  e1df43c0-7b84-4bb2-857c-760926c881f5            1    2016-10-04    Europe
# 12  2b9f288d-53ed-4f40-9e2e-5780f9501011            1    2017-04-15    Europe
# 13  38c787b2-1746-4baa-962b-7770404d25c1            0    2016-09-14    Europe
# 14  9373901b-5a8d-4f4e-acb4-6824c5ebc1e1            0    2016-09-10    Europe
# 15  d73d9a15-bcb1-441e-9571-56cbdde0e670            1    2017-07-26    Europe
# 16  95c27727-6b56-497b-ae24-cb41c5081313            1    2016-09-20    Europe
# 17  303c03d0-16a2-449f-9ac3-4ff7518845fe            0    2016-06-23    Europe
# 18  c2797dff-f373-47fd-a6c1-6ea6fd5d7274            0    2016-03-24    Europe
# 19  6a4cdbf0-a044-46e9-8d7a-429ab4a43331            0    2017-08-18    Europe
#
#    agent_specified  total_guests more_than_zero_days_in_waiting_list
# 0                1             1                                   0
# 1                0             2                                   0
# 2                1             4                                   0
# 3                1             2                                   0
# 4                1             2                                   0
# 5                0             1                                   0
# 6                1             2                                   0
# 7                1             2                                   0
# 8                1             2                                   0
# 9                1             2                                   0
# 10               1             2                                   0
# 11               1             1                                   1
# 12               1             2                                   0
# 13               1             1                                   0
# 14               1             2                                   0
# 15               1             2                                   0
# 16               1             2                                   1
# 17               1             2                                   0
# 18               0             2                                   0
# 19               1             2                                   0
#
# [20 rows x 24 columns]

# %% [markdown]
# Como estamos hablando de reservaciones en hoteles, es válido tomar en cuenta las reservaciones por temporadas. De tal forma se genera una nueva variable que se le asignará una temporada correspondiente a cada dato según su fecha de llegada (LAS TEMPORADAS SON REPRESENTATIVAS)

# %%
ds_trabajo['arrival_date'] = pd.to_datetime(ds_trabajo['arrival_date'])

# Crear una nueva columna 'season' basada en los valores de la columna 'arrival_date'
ds_trabajo['season'] = pd.cut(ds_trabajo['arrival_date'].dt.month,
                              bins=[0,3,6,9,12],
                              labels=['Winter', 'Spring', 'Summer', 'Autumn'])
ds_trabajo.head()
# Out:
#           hotel  lead_time  stays_in_weekend_nights  stays_in_week_nights  \
# 0    City Hotel   1.633333                        1                     2
# 1  Resort Hotel   0.133333                        0                     1
# 2    City Hotel   0.833333                        0                     1
# 3    City Hotel   0.866667                        2                     5
# 4    City Hotel   3.466667                        2                     5
#
#   market_segment distribution_channel  is_repeated_guest  \
# 0      Online TA                TA/TO                  0
# 1         Groups               Direct                  0
# 2      Online TA                TA/TO                  0
# 3         Groups                TA/TO                  0
# 4  Offline TA/TO                TA/TO                  0
#
#    previous_cancellations  previous_bookings_not_canceled reserved_room_type  \
# 0                       0                               0                  D
# 1                       0                               0                  A
# 2                       0                               0                  F
# 3                       0                               0                  A
# 4                       0                               0                  A
#
#    ... total_of_special_requests  reservation_status_date  \
# 0  ...                         1               2016-08-25
# 1  ...                         0               2015-11-01
# 2  ...                         2               2016-10-14
# 3  ...                         0               2016-11-29
# 4  ...                         1               2017-03-26
#
#                                      id is_canceled  arrival_date    region  \
# 0  7aa4cc6b-b92c-4061-b21d-4f9e0cac4689           1    2016-09-05  Americas
# 1  b1428f80-c56c-4ae4-91a9-6962edae08b1           0    2015-10-31    Europe
# 2  2226c018-ea20-4c4e-8f71-ea66aee70d7c           0    2016-10-13    Europe
# 3  314f56dc-2e4d-4298-9bdd-27bb008bffff           1    2016-12-12    Europe
# 4  28c75445-c603-413a-babf-ad377018b592           0    2017-03-19    Europe
#
#   agent_specified total_guests  more_than_zero_days_in_waiting_list  season
# 0               1            1                                    0  Summer
# 1               0            2                                    0  Autumn
# 2               1            4                                    0  Autumn
# 3               1            2                                    0  Autumn
# 4               1            2                                    0  Winter
#
# [5 rows x 25 columns]

# %%
frecuencia = ds_trabajo['season'].value_counts()

plt.xlabel('Estación del año')
plt.ylabel('Frecuencia')
plt.title('Distribución de la Estación del año')
frecuencia.plot(kind='bar')
plt.show()

# %% [markdown]
# Al agregar la variable `season` logramos ver que durante el verano es donde más reservas hay pero a su vez mas cancelaciones, mientras que en invierno y otoño disminuyen,
# pero son menos las cancelaciones

# %%
arrival_canceled = ds_trabajo[['season', 'is_canceled']]

arrival_canceled = arrival_canceled.groupby(['season', 'is_canceled']).size().reset_index(name='counts')
plt.xlabel('Frecuencia')
plt.ylabel('Temporada')
plt.title('Distribución de Temporada de llegada según cancelación')
sns.histplot(y='season', weights='counts', hue='is_canceled', multiple='stack', data=arrival_canceled, bins=35)
plt.show()

# %%
sns.countplot(x="season", hue="is_canceled", data=ds_trabajo)

plt.xlabel('Reservas en determinada temporada')
plt.ylabel('Frecuencia')
plt.title('Distribución del Total de Reservas en temporadas según Cancelación')

plt.show()

# %%
table = pd.pivot_table(ds_trabajo, values='is_canceled', index=['hotel', 'season'], columns=[], aggfunc=lambda x: x.sum()/len(x))
table
# Out:
#                      is_canceled
# hotel        season
# City Hotel   Winter     0.511607
#              Spring     0.583452
#              Summer     0.540011
#              Autumn     0.544220
# Resort Hotel Winter     0.323737
#              Spring     0.421555
#              Summer     0.450702
#              Autumn     0.349903

# %% [markdown]
# Vimos previamente que las variables `assigned_room_type` y `reserver_room_type` no tiene relacion directa con `is_canceled`, las reinterpretamos a ambas como "¿se le asignó el cuarto deseado?" y lo transformamos en una columna que puede darnos información

# %%
ds_trabajo['room_type_match'] = ds_trabajo['reserved_room_type'] == ds_trabajo['assigned_room_type']

# %% [markdown]
# De esta forma tengo una variable booleana que me indicará si se le asignó el cuarto deseado y qué relación tiene con is_canceled

# %%
tabla_frecuencia = pd.crosstab(ds_trabajo['room_type_match'], ds_trabajo['is_canceled'])
tabla_frecuencia.plot.bar(rot=0)

plt.title("Distribución de tipo de cuarto asignado comparado al solicitado según Cancelación")
plt.show()

# %% [markdown]
# Podemos ver que aunque no se le asignó el cuarto deseado, el porcentaje de cancelación es mucho más bajo. Tal vez se deba a una mejoría en la asignación por el mismo costo, por ejemplo

# %%
df = ds_trabajo.drop(ds_trabajo[ds_trabajo['assigned_room_type'] == 'A'].index) #SACO EL VALOR DE "A" PORQUE MOLESTA EN LA VISUALIZACION DEL GRAFICO
tabla_frecuencia = pd.crosstab(df['assigned_room_type'], df['room_type_match'])
tabla_frecuencia.plot.bar(rot=0)
plt.title("Distribución del tipo de cuarto asignado según si coincide con el reservado")
plt.show()

# %% [markdown]
# Pensamos que podemos eliminar las columnas `assigned_room_type` y `reserved_room_type` ya que podemos sacar información más interesante de la variable `room_type_match`, sumado a que facilitará el análisis dadas las numerosas categorías de ambas columnas.

# %%
ds_trabajo = ds_trabajo.drop('assigned_room_type', axis=1)
ds_trabajo = ds_trabajo.drop('reserved_room_type', axis=1)

# %% [markdown]
# Guardamos el progreso sobre el dataset en uno nuevo para trabajarlo en el siguiente notebook correspondiente al checkpoint 2.

# %%
ds_trabajo.to_csv('hotels_train_filtrado2.csv', index=False)
